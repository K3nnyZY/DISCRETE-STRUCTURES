# %%
import cv2, numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# 2. Tome de la web una imagen en formato png, bmp, jpg o jpeg. Puede ser el Logo de la Universidad del Norte o el Escudo de Junior y haga lo siguiente:
#
# - Móntelo en colab
# - Escriba el código para dado a continuación para obtener el tensor correspondiente(imagen) y su dimensión:
# - modifique la imagen, dibujando sobre ella una línea vertical, una horizontal, una diagonal principal y una secundaria; todas de $b$ pixeles de espesor.

# %%
T=cv2.imread("images//Logo_Uninorte.png")
plt.imshow(T) 

filas,columnas,capas = T.shape  # crea una matriz
b=10 # ancho de los pixeles
print(filas,columnas,capas)
# Out:
# 138 364 3

# %%
T[filas//2-b:filas//2+b,:,:]=0; 
plt.imshow(T)

# %%
T[:, columnas//2-b:columnas//2+b,:]=0; 
plt.imshow(T)

# %%
for f in range(filas): 
    T[f-1,np.abs(filas - f-1): np.abs(filas - f-1)+2*b,:]=0

plt.imshow(T)

# %%
for f in range(filas): 
    T[f-1:f-1+b,f-1:f-1+b,:]=0

plt.imshow(T)

# %% [markdown]
# #### Se Lanzan $n$ dados $T=10^i$ veces. $i=1, 2, 3$. Muestre los 3 gráficos de barras correspondientes.

# %%
n = 2  # numero de dados
T_values = [10**i for i in range(1, 4)] # veces de lanzamientos

for T in T_values:
    fa = np.zeros(5*n+1)
    for i in range(T):
        fa[np.sum(np.random.randint(1, 7, n)) - n] += 1
    
    # Normaliza las frecuencias para convertirlas en probabilidades
    fa /= T

    # Crea un gráfico de barras con las probabilidades
    plt.bar(range(n, 6*n+1), fa)
    plt.title(f'Lanzamiento de {n} dados {T} veces')
    plt.xlabel('Suma de los dados')
    plt.ylabel('Probabilidad')
    plt.grid(axis='y')
    plt.show()

# %% [markdown]
# ### Graficas en 2D
# pasos:
#
# 1. Dar valores a la variable independiente (ejex)
# 2. evaluar ejey = f(ejex)
# 3. graficar

# %%
# Paso 1: Dar valores a la variable independiente (eje x)
x = np.linspace(-10, 10, 400)

# Paso 2: Evaluar eje y = f(eje x)
# Usamos la función f(x) = x^2 como ejemplo
y = x**2

# Paso 3: Graficar
plt.plot(x, y)

# Añadimos etiquetas y título para mayor claridad
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.title('Gráfico de $f(x) = x^2$')
plt.axhline(0, color='black',linewidth=1)
plt.axvline(0, color='black',linewidth=1)

# Mostramos la gráfica
plt.grid(True)
plt.show()

# %% [markdown]
# ### coordenadas polares
# Convierte la ecuación cartesiana
# $$x^2 + y^2 = 4$$
# a coordenada polares y graficala

# %%
# despejando r tenemos que r = 2
theta = np.linspace(0, 2*np.pi, 300)
r = 2

# Convertimos las coordenadas polares a coordenadas cartesianas
x = r * np.cos(theta)
y = r * np.sin(theta)

# Graficamos el círculo
plt.plot(x, y)

# Añadimos etiquetas y título
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de $r=2$')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)

# Mostramos el gráfico
plt.show()

# %% [markdown]
# ## Grafica en 3D
# pasos:
# 1. Dar valores a la variable independiente (ejex,ejey)
# 2. Hacer el producto cartesiano (ejex,ejey,ejez),  es decir la rejilla
# 3. evaluar ejez = f(ejex,ejey)
# 4. graficar

# %% [markdown]
# ### Coordenadas rectangulares
# Grafica la funcion:
# $$z = -x^2 - y^2 + 4$$
# sobre el dominio $[-2,2]$, para $x$ y $[-2,2]$ para $y$.

# %%
# Paso 1: Dar valores a las variables independientes (eje x, eje y)
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

# Paso 2: Hacer el producto cartesiano (eje x, eje y, eje z), es decir, la rejilla
X, Y = np.meshgrid(x, y)

# Paso 3: Evaluar eje z = f(eje x, eje y)
# Usamos la función f(x, y) = sin(sqrt(x^2 + y^2)) como ejemplo
Z = -X**2 - Y**2 +4

# Paso 4: Graficar
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

# Añadimos etiquetas y título para mayor claridad
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Gráfico 3D de $f(x, y) = -x^2 - y^2 +4$')

# Mostramos la gráfica
plt.show()

# %% [markdown]
# ### Coordenadas cilindricas

# %% [markdown]
# Grafica la funcion:
# $$z = r^2 cos(3\theta)e^{-r}$$
# sobre el dominio $r \in [0,2]$ y $\theta \in [0,2\pi]$

# %%
# Paso 1: Definir el dominio
r = np.linspace(0, 2, 100)
theta = np.linspace(-2, 2*np.pi, 100)

# Paso 2: Crear la malla, producto cartesiano
R, Theta = np.meshgrid(r, theta)

# Paso 3: Evaluar la función
X = R * np.cos(Theta)
Y = R * np.sin(Theta)

z = r**2 * np.cos(3*theta) * np.exp(-r)

# Paso 4: Graficar
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

# Añadimos etiquetas y título para mayor claridad
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')

# Mostramos la gráfica
plt.show()

# %%
x = np.linspace(-5,5,100)
y  = np.linspace(-5,5,100)

x,y = np.meshgrid(x,y)

z = x**2 + y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(x,y,z,cmap="viridis")
plt.show()

# %%
x = np.linspace(-10,10,200)
y = np.linspace(-10,10,200)

x,y = np.meshgrid(x,y)
z = np.sin(x) - np.cos(x)

fig = plt.figure()
ax = fig.add_subplot(111,projection = "3d")
ax.plot_surface(x,y,z, cmap = "viridis")

plt.show()
